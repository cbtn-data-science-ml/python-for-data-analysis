# %% [markdown]
# ## Welcome to Google's Colab
#
# ### An online version of Jupyter notebook

# %%
# print Hello, world!
# Out:
# Hello, world!

# %%
# import the pandas Python package
import pandas as pd

# read a csv file from GitHub
pd.read_csv('https://raw.githubusercontent.com/cbtn-data-science-ml/python-for-data-analysis/main/datasets/mock_dataset.csv')

# %% [markdown]
# ## Markdown
# Markdown is a markup language that is a superset of HTML. Best of all, it is baked into Colab. You can toggle headings, bold, italic, links, images, indent, ordered lists, underordered lists, and much more.

# %% [markdown]
# ## Headings
#
#
# #### Lists

# %% [markdown]
# ## LaTex
#
# LaTex is used by data analysts, data scientists, mathematicians, and many other professionals to write complex math and statistics equations. LaTex is also baked into Colab. To display LaTex in a Colab text box, all you need to do is click on the pitchfork symbol in the text box editing view.

# %% [markdown]
# ![Colab_LaTex_icon.png](https://drive.google.com/uc?id=1z1kRMn2wrCTbJc2xrqMrvdRMy_8mfFtx)
#
# To enter the text edit view, double-click on a text box.
#
# ![empty_colab_text_box.png](https://drive.google.com/uc?id=1C7HsrOF3NefaqZKyb385NCfsAigZ5MUP)
#
#
# Alternatively, you can use the `$` to start and stop a LaTex command. For example, `$\pi$` will return $\pi$. If you click on the text boxes that contain LaTex, you will see the source code used to make all of the LaTex symbols you see in the Colab notebooks. Here are some examples:
#
# Simple math:
#
# $\large 1 + 1$
#
# Euler's identity:
#
# $
# \large e^{i \pi} + 1 = 0
# $

# %% [markdown]
# $ π = 3.14$

# %% [markdown]
# Checkout this [LaTex cheatsheet](https://joshua.smcvt.edu/undergradmath/undergradmath.pdf) as needed.
