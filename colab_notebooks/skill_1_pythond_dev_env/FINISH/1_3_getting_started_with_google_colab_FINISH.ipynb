# %% [markdown]
# ## Welcome to Google's Colab
# ### An online version of Jupyter notebook

# %%
# print Hello, world!
print('Hello, world!')
# Out:
# Hello, world!

# %%
# import the pandas Python package
import pandas as pd

# read a csv file from GitHub
pd.read_csv('https://raw.githubusercontent.com/cbtn-data-science-ml/python-for-data-analysis/main/datasets/mock_dataset.csv')
# Out:
#      id first_name   last_name                           email       ip_address
# 0   235     Lexine      Daouse             ldaouse0@ebay.co.uk    240.12.57.166
# 1   236    Romonda    Eberlein        reberlein1@angelfire.com   218.58.197.224
# 2   237     Joanie        Khan            jkhan2@mediafire.com    161.5.165.102
# 3   238     Joelly     Neising           jneising3@dedecms.com    236.85.227.55
# 4   239    Wilfrid     Bifield          wbifield4@engadget.com   93.178.125.245
# ..  ...        ...         ...                             ...              ...
# 95  330    Arleyne  Dassindale     adassindale2n@123-reg.co.uk   188.186.113.21
# 96  331     Bertie    Pannaman  bpannaman2o@huffingtonpost.com   149.171.15.200
# 97  332       Luis    Apedaile       lapedaile2p@goodreads.com  179.210.201.121
# 98  333      Minor     Manueli          mmanueli2q@answers.com  100.244.124.150
# 99  334      Homer      Cadany               hcadany2r@ibm.com    31.215.162.23
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Markdown
# Markdown is a markup language that is a superset of HTML. Best of all it is baked into Colab. You can toggle headings, bold, italic, links, images, indent, ordered lists, underordered lists and much more.

# %% [markdown]
# #### Headings
#
#
# #### Lists

# %% [markdown]
# ## LaTex
#
# LaTex is used by data analysists, data scientists, mathematicians and many other professionals to write complex math and statistical formulas and equations. LaTex is also baked into Colab. To display LaTex in a Colab text box, all you need to do is click on the pitchfork symbol while in the text box editing view.

# %% [markdown]
# ![Colab_LaTex_icon.png](data:image/png;base64,...)
#
# To enter the text edit view, double click on a text box.
#
# ![empty_colab_text_box.png](data:image/png;base64,...)

# %% [markdown]
# ### Simple math and Euler's identity
#
# $\large 1 + 1 = 2$
#
# Euler's identity:
#
# $
# \large e^{i \pi} + 1 = 0
# $
#
# Checkout this [LaTex cheatsheet](https://joshua.smcvt.edu/undergradmath/undergradmath.pdf) as needed.
