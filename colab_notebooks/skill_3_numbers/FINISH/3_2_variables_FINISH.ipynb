# %% [markdown]
# # Variables
# As we discussed earlier, variables are names, or placeholders, that contain values such as strings(text), numbers, and even boolean values or functions. Before diving into numbers, math operations, and strings, you should know how to write a proper variable name using best practices.
#
# ## Legality
#
# Variable can be any length consisting of uppercase and lowercase letters `A-Z`,`a-z`, digits `0-9`, and underscores `_`. Although a variable name can contain digits, the first character of a variable cannot include a digit.

# %%
# not a legal variable name
1 = 100

# %% [markdown]
# ## Undefined variables
#
# Beware: If you try to return an undefined variable, you will get a name error 😱

# %%
# m is undefined
m

# you can initialize a variable
m = ''

# %% [markdown]
# ## Return a variable
#
# If you define a variable and execute the variable name, you'll return the value of that variable. If you try to execute more than one variable, you will only get one return value per variable. In the next section, you will learn how to return multiple variables in the same code cell, using the `print()` function.

# %%
# return variables, one at a time
a = 1
a

# or you will return the value of y, not x and y
b = 2
b
# Out:
# 2

# %% [markdown]
# ## Print a variable

# %%
# you can print both values using two print() functions
# and inserting the variable inside the parenthesis (this is called an argument)
print(a)
print(b)
# Out:
# 4

# %%
# once you declare variables, you can use them in many ways
x + y
# Out:
# 9

# %%
# this also works with strings, which we will cover in depth later in the course
message = 'The values of a and b are equal to: '
# print message
print(message)

# print a + b
print(a + b)

# %% [markdown]
# ## Variable are case-senitive

# %%
# K is not the same as k
K = 4
k = 5
print(K)
print(k)
# Out:
# 4
# 5

# %% [markdown]
# ## Variable can be reassigned

# %%
# reassign the variable k
k = 10
print(k)

k = 100
print(k)
# Out:
# 10
# 100

# %% [markdown]
# ## Semantic Variable Names
#
# Variables should be meaningful, whenever possible. For example, when keeping track of points for players in a game or a customer's balance at a bank. Semantic variable names helps keep your code more readable for you and anyone else taking a look at your code.

# %%
# final scores 
high_score = 2
low_score = 1

print(high_score)
print(low_score)
print('Keith wins!')

# %% [markdown]
# ## Type Casting
# You can specify the data type of a variable with typecasting.

# %%
x = str(3)    # x = '3'
y = int(3)    # y = 3
z = float(3)  # z = 3.0

print(x)
print(y)
print(z)

print(type(x))
print(type(y))
print(type(z))
# Out:
# 3
# 3
# 3.0
# <class 'str'>
# <class 'int'>
# <class 'float'>
