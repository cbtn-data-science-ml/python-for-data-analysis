# %% [markdown]
# # Python Numbers Challenge

# %%
# assign the value 15 to the variable name: points
points = 15

# %%
# add 10 to the variable name: points
points = 25
points = points + 10

# %%
# print the value contained in the variable name: points
print(points)

# %%
# use the multiplication operator to double the points stored in the variable name: points
points = points * 2

# %%
# print the value contained in the variable name: points
print(points)

# %%
# use the multiplication operator to double the points stored in the variable name: points
points = points * 2

# %%
# divide the points between four players and store it in the variable name: points
points = points / 4

# %%
# print the value contained in the variable name: points
print(points)

# %% [markdown]
# Congrats if you got `25.0` points! 🥳

# %% [markdown]
# ## Quiz questions:
#
# 1. Which of the following are legal variable name?
#
#
# *   3rd_item = 199
# *   **first_name**
# *   **_this_id**
# *   **id_2029**
#
# 2. Which of the following are valid Python math operators?
#
# *   `*`(correct)
# *   `**`(correct)
# *   $\div$
# *   $\times$
#
# 3. Which of the following is the correct order of operations?
#
# *   **PEMDAS**
# *   PADMES
# *   DASMED
# *   None of the above
#
# 4. Variables are mutable. True or False?
#
# *   **True**
# *   False
