# %%
# write Hello, world! as a string below
"Hello, world!"

# %%
# assign the string Hello, world! to a variable named a
a = "Hello, world!"

# %%
# what is the data type of the following?
b = "34"
# use a function to verify the data type
type(b)

# %%
# what is the data type of the following?
c = False
# use a function to verify the data type
type(c)

# %%
# what is the data type of the following?
d = 9999.2
# use a function to verify the data type
type(d)

# %%
# what is the data type of the following?
e = 0
# use a function to verify the data type
type(e)

# %%
# what is the data type of the following scientific notation?
f = 290E-10
# use a function to verify the data type
type(f)
# Out:
# float

# %% [markdown]
# Quiz questions:
#
# 1. Which of the following are primitive data types?
#
#
# *   **integer**
# *   list
# *   **float**
# *   **bool**
#
# 2. Which of the following are non-primitive data types?
#
# *   **set**
# *   float
# *   **dictionary**
# *   **tuple**
#
# 3. Select all symbols can be used to create a comment in Python
#
# *   """ (correct)
# *   *
# *   \# (correct)
# *   //
#
# 4. Lists are mutable. True or False?
#
# *   **True**
# *   False
