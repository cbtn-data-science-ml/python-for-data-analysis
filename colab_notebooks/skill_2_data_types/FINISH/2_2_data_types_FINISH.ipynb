# %% [markdown]
# ## Variables
# Variables are names, or placeholders, that contain values and we will cover them in depth later in the course. For now, just know that they are placeholders. For example, `x = 1` shows the variable name `x` which is assigned a value using the `=` equal sign with a value of `1`. A common tool used with variables is the `print()` function which return the value of a variable. In this case `print(x)` will return `1`.

# %%
x = 1
print(x)
# Out:
# 1

# %% [markdown]
# ## Numbers & Bools

# %%
# Numbers and Bools
a = 5 # Integer
b = 3.14 # Float
c = True # Bool
d = False # Bool
e = 1 # Bool same as True
f = 0 # Bool same as False

# %% [markdown]
# ## Strings

# %%
# Strings (single or double quotes)
g = "Hello World" # A string of characters

# %% [markdown]
# ## Collections

# %%
# Collections
h = ["this", "is", "a", "list"] # List
i = {"this", "is", "a", "set"} # Set
j = {"I'm a":"Dictionary"} # Dictionary
k = ("this", "is", "a", "tuple") # Tuple

# %% [markdown]
# ## The `type()` Function
#
# The `type()` function return the data type of a particular Python object.

# %%
type(k)
